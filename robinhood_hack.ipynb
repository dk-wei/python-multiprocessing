# %% [markdown]
# <a href="https://colab.research.google.com/github/dwei-cn/python-tricks/blob/main/robinhood_hack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install robin-stocks
#!pip install config
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: robin-stocks in /usr/local/lib/python3.8/dist-packages (2.1.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.8/dist-packages (from robin-stocks) (39.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from robin-stocks) (2.25.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.8/dist-packages (from robin-stocks) (0.21.1)
# Requirement already satisfied: pyotp in /usr/local/lib/python3.8/dist-packages (from robin-stocks) (2.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography->robin-stocks) (1.15.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->robin-stocks) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->robin-stocks) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->robin-stocks) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->robin-stocks) (2022.12.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography->robin-stocks) (2.21)

# %%
#import config
import datetime
import pandas as pd
import robin_stocks.robinhood as r

username = 'darken.vi@hotmail.com'
password = 'WoXihuanchi0@'

today = datetime.date.today()

# ordered_columns = [
#     'name',
#     'quantity',
#     'price',
#     'average_buy_price',
#     'percent_change',
#     'equity',
#     'type',
#     'percentage'
# ]

login = r.login(username, password)

# %%
df = pd.DataFrame.from_dict(r.build_holdings())
transpose = df.T
transpose = transpose.drop(['id', 'equity_change', 'pe_ratio'], axis=1)
transpose = transpose.sort_index()

#transpose.to_csv(f'robinhood-{today}.csv', header=True, columns=ordered_columns, index=True)

# %%
df
# Out:
#                                                          AAPL  \
# price                                              138.150000
# quantity                                           0.41355200
# average_buy_price                                    120.9038
# equity                                                  57.13
# percent_change                                          14.26
# intraday_percent_change                                  0.00
# equity_change                                        7.132201
# type                                                    stock
# name                                                    Apple
# id                       450dfc6d-5510-4d40-abfb-f633b7d9be3e
# pe_ratio                                            22.552800
# percentage                                              13.22
#
#                                                          TQQQ  \
# price                                               20.470000
# quantity                                           2.00000000
# average_buy_price                                     19.8450
# equity                                                  40.94
# percent_change                                           3.15
# intraday_percent_change                                  0.00
# equity_change                                        1.250000
# type                                                      etp
# name                                   ProShares UltraPro QQQ
# id                       91f7ea28-e413-4ca4-b9fa-91f5822f8b8d
# pe_ratio                                                 None
# percentage                                               9.48
#
#                                                                       JNUG  \
# price                                                            45.480000
# quantity                                                        1.00000000
# average_buy_price                                                  44.8800
# equity                                                               45.48
# percent_change                                                        1.34
# intraday_percent_change                                               0.00
# equity_change                                                     0.600000
# type                                                                   etp
# name                     Direxion Daily Junior Gold Miners Index Bull 2...
# id                                    f1ebb4d7-fe71-4fab-b8da-e720c2e8f823
# pe_ratio                                                              None
# percentage                                                           10.53
#
#                                                            KO  \
# price                                               60.060000
# quantity                                           0.29294400
# average_buy_price                                     61.4452
# equity                                                  17.59
# percent_change                                          -2.25
# intraday_percent_change                                  0.00
# equity_change                                       -0.405786
# type                                                    stock
# name                                                Coca-Cola
# id                       bb9a01df-5982-42d4-88db-8662f23cdab5
# pe_ratio                                            26.335900
# percentage                                               4.07
#
#                                                         BRK.B  \
# price                                              309.870000
# quantity                                           0.00314800
# average_buy_price                                    317.6620
# equity                                                   0.98
# percent_change                                          -2.45
# intraday_percent_change                                  0.00
# equity_change                                       -0.024529
# type                                                    stock
# name                                       Berkshire Hathaway
# id                       a4f0cca4-79dc-4297-9c02-5bce1909cd4b
# pe_ratio                                                 None
# percentage                                               0.23
#
#                                                          SBUX  \
# price                                              105.060000
# quantity                                           0.28449500
# average_buy_price                                    105.4500
# equity                                                  29.89
# percent_change                                          -0.37
# intraday_percent_change                                  0.00
# equity_change                                       -0.110953
# type                                                    stock
# name                                                Starbucks
# id                       18c7a7ad-3527-47b4-84b4-ce4db0106531
# pe_ratio                                            37.082500
# percentage                                               6.92
#
#                                                          MSFT  \
# price                                              240.400000
# quantity                                           0.21083200
# average_buy_price                                    237.1556
# equity                                                  50.68
# percent_change                                           1.37
# intraday_percent_change                                  0.00
# equity_change                                        0.684023
# type                                                    stock
# name                                                Microsoft
# id                       50810c35-d215-4866-9758-0ada4ac79ffa
# pe_ratio                                            25.886300
# percentage                                              11.73
#
#                                                           MCD  \
# price                                              268.580000
# quantity                                           0.07488800
# average_buy_price                                    267.0655
# equity                                                  20.11
# percent_change                                           0.57
# intraday_percent_change                                  0.00
# equity_change                                        0.113418
# type                                                    stock
# name                                               McDonald's
# id                       41eac3c6-f7f7-4c4a-b696-ab9d1b913981
# pe_ratio                                            33.833000
# percentage                                               4.66
#
#                                                           UNH  \
# price                                              486.720000
# quantity                                           0.05203200
# average_buy_price                                    480.4736
# equity                                                  25.33
# percent_change                                           1.30
# intraday_percent_change                                  0.00
# equity_change                                        0.325013
# type                                                    stock
# name                                             UnitedHealth
# id                       1abfbfc7-6c65-4ded-8a97-1e7f82220b64
# pe_ratio                                            22.981300
# percentage                                               5.86
#
#                                                           ETN  \
# price                                              155.510000
# quantity                                           0.12567100
# average_buy_price                                    159.1457
# equity                                                  19.54
# percent_change                                          -2.28
# intraday_percent_change                                  0.00
# equity_change                                       -0.456902
# type                                                    stock
# name                                                    Eaton
# id                       98245487-3340-42c9-888d-1a97743466b5
# pe_ratio                                            27.231800
# percentage                                               4.52
#
#                                                          BABA
# price                                              119.950000
# quantity                                           0.22024400
# average_buy_price                                    113.5105
# equity                                                  26.42
# percent_change                                           5.67
# intraday_percent_change                                  0.00
# equity_change                                        1.418261
# type                                                      adr
# name                                                  Alibaba
# id                       b2e06903-5c44-46a4-bd42-2a696f9d68e1
# pe_ratio                                           307.886000
# percentage                                               6.11

# %%
positions_data = r.get_all_positions()
df = pd.DataFrame.from_dict(positions_data)

# %%
r.get_

# %% [markdown]
# # Options

# %%
option_trades = pd.DataFrame(r.get_all_option_orders())
#option_trades.columns

# %%
option_trades_filled = option_trades[['account_number', 'chain_symbol', 'state', 'created_at', 'quantity', 'direction', 'premium', 'opening_strategy', 'closing_strategy']]
option_trades_filled = option_trades[['chain_symbol', 'state', 'created_at', 'quantity', 'direction', 'premium', 'opening_strategy', 'closing_strategy']]

# %%
option_trades_filled = option_trades_filled[option_trades_filled['state'] == 'filled'].sort_values(by = 'chain_symbol')

# %%
option_trades_filled
# Out:
#    chain_symbol   state                   created_at quantity direction  \
# 1          MSFT  filled  2023-01-20T16:51:28.937402Z  1.00000    credit
# 45          NIO  filled  2023-01-18T17:58:05.785306Z  1.00000     debit
# 51          NIO  filled  2023-01-13T19:52:01.292366Z  1.00000    credit
# 53          NIO  filled  2023-01-13T17:52:18.909366Z  1.00000     debit
# 55          NIO  filled  2023-01-12T08:51:25.769899Z  1.00000    credit
# 15         SBUX  filled  2023-01-19T20:00:48.877503Z  1.00000     debit
# 46         SBUX  filled  2023-01-18T16:58:38.464311Z  1.00000    credit
# 41          SPY  filled  2023-01-18T18:09:05.241752Z  1.00000    credit
# 30          SVM  filled  2023-01-19T17:20:15.492563Z  1.00000     debit
# 26          UNH  filled  2023-01-19T17:46:42.561636Z  1.00000    credit
# 32          WFC  filled  2023-01-19T17:02:48.445332Z  1.00000     debit
# 36          WFC  filled  2023-01-19T16:24:23.155755Z  1.00000    credit
# 37          WFC  filled  2023-01-19T16:18:11.801837Z  1.00000     debit
# 49          WFC  filled  2023-01-17T16:32:25.637577Z  1.00000    credit
#
#         premium   opening_strategy   closing_strategy
# 1   80.00000000   short_put_spread               None
# 45  16.00000000               None          short_put
# 51  15.00000000          short_put               None
# 53   4.00000000               None          short_put
# 55   4.00000000          short_put               None
# 15  18.00000000               None  short_call_spread
# 46  34.00000000  short_call_spread               None
# 41  45.00000000  short_call_spread               None
# 30  40.00000000          long_call               None
# 26  80.00000000   short_put_spread               None
# 32  16.00000000               None  short_call_spread
# 36  12.00000000  short_call_spread               None
# 37  43.00000000               None   short_put_spread
# 49  20.00000000   short_put_spread               None

# %%
option_trades_filled['profit'] = option_trades_filled.apply(lambda x: float(x['premium']) * float(x['quantity']) if x['direction'] == 'credit' else -1 * float(x['premium']) * float(x['quantity']),
                           axis = 1)

# %%
option_trades_filled
# Out:
#    account_number chain_symbol   state                   created_at quantity  \
# 1       923872220         MSFT  filled  2023-01-20T16:51:28.937402Z  1.00000
# 45      923872220          NIO  filled  2023-01-18T17:58:05.785306Z  1.00000
# 51      923872220          NIO  filled  2023-01-13T19:52:01.292366Z  1.00000
# 53      923872220          NIO  filled  2023-01-13T17:52:18.909366Z  1.00000
# 55      923872220          NIO  filled  2023-01-12T08:51:25.769899Z  1.00000
# 15      923872220         SBUX  filled  2023-01-19T20:00:48.877503Z  1.00000
# 46      923872220         SBUX  filled  2023-01-18T16:58:38.464311Z  1.00000
# 41      923872220          SPY  filled  2023-01-18T18:09:05.241752Z  1.00000
# 30      923872220          SVM  filled  2023-01-19T17:20:15.492563Z  1.00000
# 26      923872220          UNH  filled  2023-01-19T17:46:42.561636Z  1.00000
# 32      923872220          WFC  filled  2023-01-19T17:02:48.445332Z  1.00000
# 36      923872220          WFC  filled  2023-01-19T16:24:23.155755Z  1.00000
# 37      923872220          WFC  filled  2023-01-19T16:18:11.801837Z  1.00000
# 49      923872220          WFC  filled  2023-01-17T16:32:25.637577Z  1.00000
#
#    direction      premium   opening_strategy   closing_strategy  profit
# 1     credit  80.00000000   short_put_spread               None    80.0
# 45     debit  16.00000000               None          short_put   -16.0
# 51    credit  15.00000000          short_put               None    15.0
# 53     debit   4.00000000               None          short_put    -4.0
# 55    credit   4.00000000          short_put               None     4.0
# 15     debit  18.00000000               None  short_call_spread   -18.0
# 46    credit  34.00000000  short_call_spread               None    34.0
# 41    credit  45.00000000  short_call_spread               None    45.0
# 30     debit  40.00000000          long_call               None   -40.0
# 26    credit  80.00000000   short_put_spread               None    80.0
# 32     debit  16.00000000               None  short_call_spread   -16.0
# 36    credit  12.00000000  short_call_spread               None    12.0
# 37     debit  43.00000000               None   short_put_spread   -43.0
# 49    credit  20.00000000   short_put_spread               None    20.0

# %%
option_trades_filled['profit'].sum()
# Out:
# 153.0
