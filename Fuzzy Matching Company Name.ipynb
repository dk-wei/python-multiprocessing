# %% [markdown]
# - csdf_cs_dnac_appliances
# - cdna_appliances

# %%
import pandas as pd
import os
from tqdm import tqdm

# %%
pwd
# Out:
# '/home/jupyter/sw_xray_analysis/telemetry'

# %%
cr_party_name = pd.read_csv('/home/jupyter/DATA/input/telemetry_analysis/cr_party_name.csv', index_col=0)
sr_customer_name = pd.read_csv('/home/jupyter/DATA/input/telemetry_analysis/sr_customer_name.csv', index_col=0)

# %%
sr_customer_name
# Out:
#                                        customer_gu_name
# 0                                  1-800-FLOWERSCOM INC
# 1                    1199 SEIU LEAGUE JOB SECURITY FUND
# 2                                            3M COMPANY
# 3                                  3MD TECHNOLOGIES INC
# 4                                             8X8, INC.
# ...                                                 ...
# 3614                                     ZOLIONDA GROUP
# 3615                         ZUHLKE TECHNOLOGY GROUP AG
# 3616  ZURCHER HOCHSCHULE FUR ANGEWANDTE WISSENSCHAFT...
# 3617                          ZURICH INSURANCE GROUP AG
# 3618  ZWEITES DEUTSCHES FERNSEHEN GEMEINNUTZIGE ANST...
#
# [3619 rows x 1 columns]

# %%
cr_party_name
# Out:
#                                           cr_party_name
# 0                              1-800-FLOWERS RETAIL INC
# 1                                        1199SEIU FUNDS
# 2                  16TH CIRCUIT COURT OF JACKSON COUNTY
# 3                             3-BANKEN BETEILIGUNG GMBH
# 4                                                39 IOS
# ...                                                 ...
# 4874                                       ZOETIS EXTON
# 4875                                     ZOLIONDA GROUP
# 4876                              ZUHLKE ENGINEERING AG
# 4877  ZURCHER HOCHSCHULE FUR ANGEWANDTE WISSENSCHAFT...
# 4878                        ZYDUS CADILA HEALTHCARE LTD
#
# [4879 rows x 1 columns]

# %% [markdown]
# # Company name matching
# ## Play around with `fuzzywuzzy` package
#
# Ref 1: https://github.com/seatgeek/fuzzywuzzy
# Ref 2: http://chairnerd.seatgeek.com/fuzzywuzzy-fuzzy-string-matching-in-python/
#
# Fuzzy string matching uses [Levenshtein](https://en.wikipedia.org/wiki/Levenshtein_distance) Distance to calculate the differences between sequence.

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Exact match, the Levenshtein Distance of two string. 
fuzz.ratio("California", "California State")
# Out:
# 77

# %%
# The ratio of most similar substring.
fuzz.partial_ratio("California", "California State")
# Out:
# 100

# %%
# Measure of the sequences' similarity sorting the token before comparing.
# tokenizing the string in question, sorting the tokens alphabetically, and then joining them back into a string.
fuzz.token_sort_ratio("State California", "California State")
# Out:
# 100

# %%
# Find all alphanumeric tokens in each string.
# tokenize both strings, but instead of immediately sorting and comparing, we split the tokens into two groups: intersection and remainder. We use those sets to build up a comparison string.
fuzz.token_set_ratio("State California", "State  State California")
# Out:
# 100

# %%
fuzz.token_set_ratio("1-800-FLOWERSCOM INC", "1-800-FLOWERS RETAIL INC")
# Out:
# 77

# %%
choices = ["California", "Los Angeles", "San Jose", "San Bernardino"]
process.extract("L.A", choices, limit=2)
# Out:
# [('Los Angeles', 60), ('California', 57)]

# %%
process.extractOne("L.A", choices)
# Out:
# ('Los Angeles', 60)

# %% [markdown]
# ## Implement fuzzywuzzy on our data

# %%
choices = cr_party_name['cr_party_name'].tolist()
process.extract("1-800-FLOWERSCOM INC", choices, limit=2, scorer=fuzz.token_set_ratio)
# Out:
# [('1-800-FLOWERS RETAIL INC', 77), ('ACT, INC', 60)]

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold = 75, limit =3, scorer = fuzz.token_set_ratio):
    
    """
    df_1: left table to join
    df_2: right table to join 
    key1: key column of left table 
    key2: key column of right table 
    threshold: how close the matchs should be return to match, based on Levenshtein distance
    limit: amount of matches will return
    scorer: scorer will be used in matching
    return: dataframe with both keys and matches
    """
    
    choice_list = df_2[key2].tolist()
    
    m1 = df_1[key1].apply(lambda x: process.extract(x, choice_list, limit = limit, scorer = scorer))
    df_1['best matches'] = m1
    
    m2 = df_1['best matches'].apply(lambda x:  [i[0] for i in x if i[1] >= threshold][0] 
                                        if len([i[0] for i in x if i[1] >= threshold]) > 0 
                                        else '')

    df_1['top match'] = m2
    
    
    
    return df_1

# %%
# run time: 25mins
df = fuzzy_merge(sr_customer_name, 
                 cr_party_name, 
                 'customer_gu_name', 
                 'cr_party_name', 
                 threshold = 75
                )

# %%
df
# Out:
#                                                                 customer_gu_name  \
# 0     1-800-FLOWERSCOM INC
# 1     1199 SEIU LEAGUE JOB SECURITY FUND
# 2     3M COMPANY
# 3     3MD TECHNOLOGIES INC
# 4     8X8, INC.
# ...         ...
# 3614  ZOLIONDA GROUP
# 3615  ZUHLKE TECHNOLOGY GROUP AG
# 3616  ZURCHER HOCHSCHULE FUR ANGEWANDTE WISSENSCHAFTEN ZHAW
# 3617  ZURICH INSURANCE GROUP AG
# 3618  ZWEITES DEUTSCHES FERNSEHEN GEMEINNUTZIGE ANSTALT DES OEFFENTLICHEN RECHTS
#
#                                                                                                                                                                             best matches  \
# 0     [(1-800-FLOWERS RETAIL INC, 77), (ACT, INC, 60), (ADP INC, 60)]
# 1     [(STATE SECURITY AGENCY, 55), (SECURITAS NORGE AS, 54), (SECURITIES AND EXCHANGE COMMISSION US, 54)]
# 2     [(3M COMPANY, 100), (AA ACQUISITION COMPANY LTD, 82), (ABU DHABI AIRPORTS COMPANY, 82)]
# 3     [(AGILENT TECHNOLOGIES INC US, 89), (FORESCOUT TECHNOLOGIES INC, 89), (KEYSIGHT TECHNOLOGIES, INC., 89)]
# 4     [(NUTANIX C O 8X8 INC, 100), (KOFAX INC, 62), (1-800-FLOWERS RETAIL INC, 60)]
# ...                                                                             ...
# 3614  [(ZOLIONDA GROUP, 100), (NEC GROUP, 71), (SGH GROUP, 71)]
# 3615  [(MILLENNIUM TECHNOLOGY GROUP, 76), (TECHNOLOGY GROUP SOLUTIONS LLC, 76), (SMA SOLAR TECHNOLOGY AG, 72)]
# 3616  [(ZURCHER HOCHSCHULE FUR ANGEWANDTE WISSENSCHAFTEN ZHAW, 100), (PAEDAGOGISCHE HOCHSCHULE ZURICH, 57), (FRAUNHOFER-GESELLSCHAFT ZUR FOERDERUNG DER ANGEWANDTEN FORSCHUNG EV, 53)]
# 3617  [(AG INSURANCE SA, 89), (DB INSURANCE, 86), (EMC INSURANCE GROUP INC., 79)]
# 3618  [(ZDF ZWEITES DEUTSCHES FERNSEHEN, 93), (HELMHOLTZ ZENTRUM MUENCHEN DEUTSCHES FORSCHUNGSZENTRUM FUER GESUNDHEIT UND UMWELT GMBH, 48), (DEUTSCHES ELEKTRONEN SYNCHROTRON DESY, 43)]
#
#                                                   top match
# 0     1-800-FLOWERS RETAIL INC
# 1
# 2     3M COMPANY
# 3     AGILENT TECHNOLOGIES INC US
# 4     NUTANIX C O 8X8 INC
# ...                   ...
# 3614  ZOLIONDA GROUP
# 3615  MILLENNIUM TECHNOLOGY GROUP
# 3616  ZURCHER HOCHSCHULE FUR ANGEWANDTE WISSENSCHAFTEN ZHAW
# 3617  AG INSURANCE SA
# 3618  ZDF ZWEITES DEUTSCHES FERNSEHEN
#
# [3619 rows x 3 columns]

# %%
# Display full (no truncate) dataframe

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', -1)

# %%
df.head(100)
# Out:
#                                                    customer_gu_name  \
# 0   1-800-FLOWERSCOM INC
# 1   1199 SEIU LEAGUE JOB SECURITY FUND
# 2   3M COMPANY
# 3   3MD TECHNOLOGIES INC
# 4   8X8, INC.
# 5   ?BANK OZK
# 6   A LOACKER SPA
# 7   A-LEHDET OY
# 8   A. T. STILL UNIVERSITY OF HEALTH SCIENCES
# 9   AABENRAA KOMMUNE
# 10  AALBORG KOMMUNE
# 11  AALBORG UNIVERSITET
# 12  AAR CORPORATION
# 13  AARON'S INC
# 14  AB ELECTROLUX
# 15  ABB LTD
# 16  ABBOTT LABORATORIES
# 17  ABBVIE INC
# 18  ABC BENEFITS CORPORATION
# 19  ABELSON-TAYLOR INC
# 20  ABERDEEN PROVING GROUND POST C.
# 21  ABH FINANCIAL LTD
# 22  ABH HOLDINGS SA
# 23  ABM INDUSTRIES INC
# 24  ABRIS DISTRIBUTION KAZAKHSTAN ABRIS DISTRIBUTION KAZAKHSTAN TOO
# 25  ABSA GROUP LTD
# 26  ABU DHABI AIRPORTS COMPANY
# 27  ABU DHABI CUSTOMS DEPT
# 28  ABU DHABI DEPT OF FINANCE
# 29  ABU DHABI HEALTH SERVICES COMPANY  PSC
# 30  ABU DHABI INVESTMENT AUTHORITY
# 31  ABU DHABI QUALITY AND CONFORMITY COUNCIL
# 32  ABU DHABI TERMINALS
# 33  ACADEMISCH MEDISCH CENTRUM
# 34  ACADEMISCH ZIEKENHUIS LEIDEN
# 35  ACADEMISCH ZIEKENHUIS MAASTRICHT
# 36  ACADIA HEALTHCARE COMPANY INC
# 37  ACCENTURE PUBLIC LTD COMPANY
# 38  ACCOLADE WINES AUSTRALIA LTD
# 39  ACCOUNTANT GENERAL DEPT
# 40  ACE LTD
# 41  ACERO SCHOOL DISTRICT
# 42  ACH COLOMBIA S A
# 43  ACHMEA BV
# 44  ACHMEA HEALTH CENTERS BV
# 45  ACROMAS HOLDINGS LTD
# 46  ACS ACTIVIDADES DE CONSTRUCCION Y SERVICIOS SA
# 47  ACT, INC
# 48  ACTIVISION BLIZZARD INC
# 49  ADENA HEALTH SYSTEM
# 50  ADIDAS AG
# 51  ADITYA BIRLA MANAGEMENT CORPORATION PRIVATE LTD
# 52  ADMINISTRADOR DE INFRAESTRUCTURAS FERROVIARIAS
# 53  ADOBE SYSTEMS INC
# 54  ADUNO HOLDING AG
# 55  ADVANCE AUTO PARTS INC
# 56  ADVANCED ENERGY INDUSTRIES INC
# 57  ADVANCED IT CONCEPTS INC
# 58  ADVANCED NETWORK MANAGEMENT INC
# 59  ADVANCED UNIBYTE GMBH
# 60  ADVANTEST CORPORATION
# 61  ADVENTIST HEALTH SYSTEMSUNBELT INC
# 62  ADVENTIST HEALTH SYSTEMWEST
# 63  ADVERTISING SPECIALTY INSTITUTE INC
# 64  AECOM TECHNOLOGY CORPORATION
# 65  AERA ENERGY LLC
# 66  AEROJET ROCKETDYNE OPERATIONS
# 67  AEROPORTS DE MONTREAL
# 68  AEROPORTS DE PARIS
# 69  AETNA INC.
# 70  AFLAC INC
# 71  AFNI INC
# 72  AFREXIM BANK
# 73  AG2R
# 74  AGCO CORPORATION
# 75  AGDER IKT DRIFTSSENTER IKS
# 76  AGEAS  SA
# 77  AGENCY FOR SCIENCE TECHNOLOGY & RESEARCH
# 78  AGFA GEVAERT NV
# 79  AGILENT TECHNOLOGIES INC
# 80  AGL ENERGY LTD
# 81  AGROPUR COOPERATIVE
# 82  AGROSTROJ PELHRIMOV AS
# 83  AGUA CALIENTE BAND OF CAHUILLA INDIANS
# 84  AHEAD LLC
# 85  AHT GLOBAL
# 86  AIA GROUP LTD
# 87  AIR CANADA
# 88  AIRBNB INC
# 89  AIRBUS SAS
# 90  AIRPORTS OF THAILAND PUBLIC COMPANY LTD
# 91  AIRQUAY COMPANY LTD
# 92  AJK ENTERPRISES INC
# 93  AKBANK T A S
# 94  AKLAGARMYNDIGHETEN
# 95  AKRON PUBLIC SCHOOLS
# 96  AL GHURAIR GROUP LLC
# 97  AL SANAD INFORMATION TECHNOLOGY SERVICES
# 98  ALARM.COM INCORPORATED
# 99  ALASKA HEART INSTITUTE LLC
#
#                                                                                                                                                              best matches  \
# 0   [(1-800-FLOWERS RETAIL INC, 77), (ACT, INC, 60), (ADP INC, 60)]
# 1   [(STATE SECURITY AGENCY, 55), (SECURITAS NORGE AS, 54), (SECURITIES AND EXCHANGE COMMISSION US, 54)]
# 2   [(3M COMPANY, 100), (AA ACQUISITION COMPANY LTD, 82), (ABU DHABI AIRPORTS COMPANY, 82)]
# 3   [(AGILENT TECHNOLOGIES INC US, 89), (FORESCOUT TECHNOLOGIES INC, 89), (KEYSIGHT TECHNOLOGIES, INC., 89)]
# 4   [(NUTANIX C O 8X8 INC, 100), (KOFAX INC, 62), (1-800-FLOWERS RETAIL INC, 60)]
# 5   [(?BANK OZK, 100), (MT BANK, 73), (TD BANK, 73)]
# 6   [(A LOACKER SPA, 100), (ENI SPA, 60), (ROCHE FARMA SA, 59)]
# 7   [(A-LEHDET OY, 100), (VIESTILEHDET OY, 69), (MEDBIT OY, 60)]
# 8   [(A. T. STILL UNIVERSITY OF HEALTH SCIENCES, 100), (UNIVERSITY OF IOWA, 84), (UNIVERSITY OF UTAH, 84)]
# 9   [(AABENRAA KOMMUNE, 100), (AALBORG KOMMUNE, 77), (FAXE KOMMUNE, 74)]
# 10  [(AALBORG KOMMUNE, 100), (AABENRAA KOMMUNE, 77), (SKANDERBORG KOMMUNE, 76)]
# 11  [(AALBORG UNIVERSITET, 100), (AARHUS UNIVERSITET, 81), (UMEAA UNIVERSITET, 79)]
# 12  [(AAR CORPORATION, 100), (AMWAY CORPORATION, 88), (KAO CORPORATION, 87)]
# 13  [(ARINC INC, 70), (ITRON INC, 70), (JSC CROC INC, 70)]
# 14  [(ELECTROLUX HOME PRODUCTS PTY LIMITED, 87), (ELECTROLUX HOME PRODUCTS PTY LTD, 87), (PGE ELECTRA S A, 57)]
# 15  [(ASB BANK LTD, 74), (BB&T, 73), (IAG LTD, 71)]
# 16  [(VIMTA LABORATORIES, 80), (CHARLES RIVER LABORATORIES INC, 77), (GENESYS TELECOMMUNICATIONS LABORATORIES INC, 77)]
# 17  [(ABBVIE, 100), (MEDAVIE INC, 76), (AFNI INC, 67)]
# 18  [(ABC BENEFITS CORPORATION, 100), (AAR CORPORATION, 85), (IHI CORPORATION, 85)]
# 19  [(ABELSON-TAYLOR INC, 100), (VITAL IMAGES INC, 65), (ALLISON TRANSMISSION INC, 62)]
# 20  [(ABERDEEN PROVING GROUND, 100), (ABERDEEN PROVING GROUND POST C., 100), (DEUTSCHE POST DHL GROUP, 57)]
# 21  [(CATHAY FINANCIAL HOLDING COMPANY LTD, 87), (FINANCIAL TECHNOLOGIES INDIA LTD, 87), (FINANCIAL TIMES ELECTRONIC PUBLISHING LTD, 87)]
# 22  [(SOUTH32 SA COAL HOLDINGS PROPRIETARY LTD, 85), (SPAR HOLDING AG, 80), (SEAS-NVE HOLDING AS, 71)]
# 23  [(ABM INDUSTRIES, 100), (ADVANCED ENERGY INDUSTRIES INC, 88), (BORDER STATES INDUSTRIES INC, 88)]
# 24  [(ABRIS DISTRIBUTION KAZAKHSTAN, 100), (WESCO DISTRIBUTION INC, 71), (VATTENFALL ELDISTRIBUTION AB, 59)]
# 25  [(ABSA GROUP LTD, 100), (BGL GROUP LTD, 82), (ABC GROUP  CANADA  LTD, 78)]
# 26  [(ABU DHABI AIRPORTS COMPANY, 100), (3M COMPANY, 82), (ABU DHABI GAS INDUSTRIES COMPANY LTD GASCO, 79)]
# 27  [(ABU DHABI CUSTOMS, 100), (ABU DHABI TERMINALS, 64), (ABU DHABI INVESTMENT AUTHORITY, 62)]
# 28  [(DEPARTMENT OF FINANCE ABU DHABI, 89), (DEPT OF FINANCE AND SERVICES, 75), (DEPT OF TREASURY AND FINANCE VICTORIA POLICE, 75)]
# 29  [(SEHA ABU DHABI HEALTH SERVICES COMPANY, 94), (GC SERVICES, 84), (MATER HEALTH SERVICES, 83)]
# 30  [(ABU DHABI INVESTMENT AUTHORITY, 100), (ABU DHABI CUSTOMS, 69), (ABU DHABI TERMINALS, 64)]
# 31  [(ABU DHABI QUALITY AND CONFORMITY COUNCIL, 100), (ABU DHABI CUSTOMS, 69), (MUNICIPALITY OF ABU DHABI CITY, 69)]
# 32  [(ABU DHABI TERMINALS, 100), (ABU DHABI CUSTOMS, 72), (ABU DHABI COMMERCIAL BANK, 68)]
# 33  [(ACADEMISCH MEDISCH CENTRUM, 100), (ERASMUS MEDISCH CENTRUM ROTTERDAM, 73), (LEIDS UNIVERSITAIR MEDISCH CENTRUM, 73)]
# 34  [(ACADEMISCH ZIEKENHUIS MAASTRICHT, 86), (ACADEMISCH MEDISCH CENTRUM, 63), (STICHTING JEROEN BOSCH ZIEKENHUIS, 59)]
# 35  [(ACADEMISCH ZIEKENHUIS MAASTRICHT, 100), (GEMEENTE MAASTRICHT, 69), (STICHTING JEROEN BOSCH ZIEKENHUIS, 65)]
# 36  [(ACADIA HEALTHCARE COMPANY INC, 100), (3M COMPANY, 82), (UCSD HEALTHCARE, 80)]
# 37  [(ACCENTURE, 100), (THK COMPANY LTD, 85), (3M COMPANY, 82)]
# 38  [(ACCOLADE WINES AUSTRALIA LTD, 100), (I P AUSTRALIA, 82), (JBS AUSTRALIA PTY LTD, 76)]
# 39  [(BANCO GENERAL, 70), (SINGAPORE GENERAL HOSPITAL BIOMEDICAL ENGINEERING DEPT, 69), (GENERALITAT DE CATALUA, 62)]
# 40  [(CEAT LTD, 80), (BAPTCARE LTD, 74), (AXONEX LTD, 71)]
# 41  [(ACERO SCHOOL DISTRICT, 100), (ADMINISTRATIVE SCHOOL DISTRICT 1 OF DESCHUTES COUNTY, 83), (ANNE ARUNDEL COUNTY PUBLIC SCHOOL DISTRICT, 83)]
# 42  [(ACH COLOMBIA S A, 100), (BANCOLOMBIA S A, 84), (DAXA COLOMBIA SA, 75)]
# 43  [(ACHMEA HOLDING NV, 80), (AHEAD LLC, 56), (MLB ADVANCED MEDIA, 52)]
# 44  [(UTMB HEALTH, 71), (AVERA HEALTH, 67), (NAVICENT HEALTH, 67)]
# 45  [(AIR NEW ZEALAND AIRCRAFT HOLDINGS LTD, 75), (ANGLO AMERICAN METALLURGICAL COAL HOLDINGS LTD, 75), (ARICENT TECHNOLOGIES HOLDINGS LTD, 75)]
# 46  [(BBVA SERVICIOS SA, 83), (SERVICIOS LIVERPOOL SA DE CV, 70), (SERVICIOS INDUSTRIALES PENOLES SA DE CV, 56)]
# 47  [(ACT, INC, 100), (ARINC INC, 75), (MARCO INC, 75)]
# 48  [(CABLEVISION LIGHTPATH INC, 62), (ACT, INC, 60), (ADP INC, 60)]
# 49  [(ADENA HEALTH SYSTEM, 100), (ALLINA HEALTH SYSTEM, 87), (BJC HEALTH SYSTEM, 87)]
# 50  [(ADIDAS AG, 100), (ADIDAS AMERICA INC, 80), (AUDI AG, 75)]
# 51  [(AAR CORPORATION, 85), (IHI CORPORATION, 85), (KAO CORPORATION, 85)]
# 52  [(ADIF ADMINISTRADOR DE INFRAESTRUCTURAS, 93), (DEPT OF ADMINISTRATION WISCONSIN, 51), (CENTRO NACIONAL DE PESQUISA EM ENERGIA E MATERIAIS, 50)]
# 53  [(ADOBE SYSTEMS INC, 100), (BAE SYSTEMS INC, 88), (ADOBE SYSTEMS INCORPORATED, 87)]
# 54  [(SPAR HOLDING AG, 80), (HELVETIA HOLDING AG, 77), (POLYTEC HOLDING AG, 77)]
# 55  [(ADVANCED IT CONCEPTS INC, 70), (ADVANCED AUTO, 69), (ADVANCED ENERGY INDUSTRIES INC, 62)]
# 56  [(ADVANCED ENERGY INDUSTRIES INC, 100), (ABM INDUSTRIES, 83), (CHART INDUSTRIES INC, 82)]
# 57  [(ADVANCED IT CONCEPTS INC, 100), (ADVANCED AUTO, 76), (3MD INC DBA DENALI ADVANCED INTEGRATION, 67)]
# 58  [(ADVANCED NETWORK MANAGEMENT, 100), (ADVANCED AUTO, 76), (NHS MANAGEMENT, L.L.C., 71)]
# 59  [(ADVANCED UNIBYTE GMBH, 100), (ADVANCED AUTO, 76), (IGUS GMBH, 62)]
# 60  [(AAR CORPORATION, 85), (IHI CORPORATION, 85), (KAO CORPORATION, 85)]
# 61  [(ADVENTIST HEALTH SYSTEMSUNBELT INC, 100), (ADVENTIST HEALTH SYSTEMWEST, 82), (ADVENTIS HEALTH SYSTEMS, 81)]
# 62  [(ADVENTIST HEALTH SYSTEMWEST, 100), (ADVENTIS HEALTH SYSTEMS, 92), (ADVENTIST HEALTH SYSTEMSUNBELT INC, 82)]
# 63  [(ADVERTISING SPECIALTY INSTITUTE INC, 100), (SAS INSTITUTE INC, 87), (AXIS SPECIALTY U.S. SERVICES, INC., 64)]
# 64  [(CHAO SHI JIE INTERNATIONAL TECHNOLOGY (GUANGZHOU) CORPORATION, 88), (HONG KONG SCIENCE & TECHNOLOGY PARKS CORPORATION, 88), (AAR CORPORATION, 85)]
# 65  [(AERA ENERGY LLC, 100), (CENTERPOINT ENERGY HOUSTON ELECTRIC LLC, 80), (CPS ENERGY, 75)]
# 66  [(INC AEROJET ROCKETDYNE OF DE, 78), (SYDNEY AIRPORT CORPORATION LTD, 64), (SYDNEY AIRPORTS CORPORATION LTD, 63)]
# 67  [(AEROPORTS DE MONTREAL, 100), (ECOLE POLYTECHNIQUE DE MONTREAL, 69), (UNIVERSITE DE MONTREAL Q34252, 69)]
# 68  [(AEROPORTS DE MONTREAL, 80), (DUBAI AIRPORTS, 69), (AIRPORTS OF THAILAND PLC, 57)]
# 69  [(AMGEN INC, 78), (ACT, INC, 75), (AMSNET INC, 74)]
# 70  [(ACT, INC, 75), (AFLAC GROUP 1932 WYNNTON ROAD, 71), (AFNI INC, 71)]
# 71  [(AFNI INC, 100), (NIKE, INC., 75), (AMGEN INC, 71)]
# 72  [(AFREXIM BANK, 100), (MT BANK, 73), (TD BANK, 73)]
# 73  [(AG2R, 100), (AGROPUR, 55), (LEAR, 50)]
# 74  [(AGCO CORPORATION, 100), (KAO CORPORATION, 90), (AAR CORPORATION, 85)]
# 75  [(AGDER IKT DRIFTSSENTER IKS, 100), (SPIT??ER FRUTIGEN MEIRINGEN INTERLAKEN AG, 52), (BUFDIR IKT ENHETEN, 50)]
# 76  [(BUNGE SA, 62), (SOLAR AS, 62), (AES GENER SA, 60)]
# 77  [(AGENCY FOR SCIENCE TECHNOLOGY AND RESEARCH, 100), (NATIONAL SCIENCE AND TECHNOLOGY DEVELOPMENT AGENCY, 79), (GOVERNMENT TECHNOLOGY AGENCY, 76)]
# 78  [(AGFA GEVAERT NV, 100), (GRAMMER AG, 56), (AES GENER SA, 52)]
# 79  [(AGILENT TECHNOLOGIES INC US, 100), (UBER TECHNOLOGIES INC, 86), (VENTURE TECHNOLOGIES INC, 83)]
# 80  [(AGL ENERGY LTD, 100), (GMR ENERGY LTD, 86), (ENVISION ENERGY LTD, 83)]
# 81  [(AGROPUR, 100), (ARKANSAS ELECTRIC COOPERATIVE CORPO, 73), (SEMINOLE ELECTRIC COOPERATIVE, INC., 73)]
# 82  [(AGROSTROJ PELHRIMOV AS, 100), (SOITRON GROUP AS, 53), (LEO PHARMA AS, 51)]
# 83  [(AGUA CALIENTE BAND OF CAHUILLA INDIANS, 100), (MORONGO BAND OF MISSION INDIANS INC, 60), (BANK OF CHINA LIMITED, 58)]
# 84  [(AHEAD LLC, 100), (CITADEL LLC, 60), (AERA ENERGY LLC, 58)]
# 85  [(AHT GLOBAL, 100), (ALLIANZ GLOBAL INVESTORS TAIWAN LTD, 75), (CISCO IT INTERNAL GLOBAL, 75)]
# 86  [(ABSA GROUP LTD, 89), (ABC GROUP  CANADA  LTD, 82), (ANZ BANKING GROUP LTD, 82)]
# 87  [(AIR CANADA, 100), (NAV CANADA, 80), (ABC GROUP  CANADA  LTD, 75)]
# 88  [(AIRBNB UK LTD, 75), (ARINC INC, 74), (ITRON INC, 74)]
# 89  [(AIRBUS DEFENCE & SPACE EDIFICIO INFORMATICA, 75), (AIRBUS DEFENCE AND SPACE GMBH, 75), (AIRBUS FRANCE, 75)]
# 90  [(AIRPORTS OF THAILAND PLC, 91), (THK COMPANY LTD, 85), (AUTOLIV THAILAND COMPANY LTD, 83)]
# 91  [(AIRQUAY, 100), (THK COMPANY LTD, 85), (3M COMPANY, 82)]
# 92  [(TERANET ENTERPRISES INC, 88), (WELLS ENTERPRISES INC, 88), (LACKS ENTERPRISES, 79)]
# 93  [(AKBANK, 100), (ALPHA BANK S.A., 69), (FINANSBANK A S, 69)]
# 94  [(AKLAGARMYNDIGHETEN, 100), (HELENA AGRI, 55), (LANDSTINGET DALARNA, 54)]
# 95  [(AKRON PUBLIC SCHOOLS, 100), (DETROIT PUBLIC SCHOOLS, 82), (FAIRFAX COUNTY PUBLIC SCHOOLS, 82)]
# 96  [(CIT GROUP NJ LLC, 72), (NEC GROUP, 71), (SGH GROUP, 71)]
# 97  [(AL SANAD INFORMATION TECHNOLOGY SERVICES, 100), (MISSISSIPPI DEPT OF INFORMATION TECHNOLOGY SERVICES, 87), (UNIV OF TORONTO INFORMATION & TECHNOLOGY SERVICES, 87)]
# 98  [(ALARM.COM INCORPORATED, 100), (CARGILL INCORPORATED, 75), (ADOBE SYSTEMS INCORPORATED, 71)]
# 99  [(ALASKA HEART INSTITUTE LLC, 100), (SAS INSTITUTE INC, 69), (NATIONAL INSTITUTES OF HEALTH, 58)]
#
#                                                         top match
# 0   1-800-FLOWERS RETAIL INC
# 1
# 2   3M COMPANY
# 3   AGILENT TECHNOLOGIES INC US
# 4   NUTANIX C O 8X8 INC
# 5   ?BANK OZK
# 6   A LOACKER SPA
# 7   A-LEHDET OY
# 8   A. T. STILL UNIVERSITY OF HEALTH SCIENCES
# 9   AABENRAA KOMMUNE
# 10  AALBORG KOMMUNE
# 11  AALBORG UNIVERSITET
# 12  AAR CORPORATION
# 13
# 14  ELECTROLUX HOME PRODUCTS PTY LIMITED
# 15
# 16  VIMTA LABORATORIES
# 17  ABBVIE
# 18  ABC BENEFITS CORPORATION
# 19  ABELSON-TAYLOR INC
# 20  ABERDEEN PROVING GROUND
# 21  CATHAY FINANCIAL HOLDING COMPANY LTD
# 22  SOUTH32 SA COAL HOLDINGS PROPRIETARY LTD
# 23  ABM INDUSTRIES
# 24  ABRIS DISTRIBUTION KAZAKHSTAN
# 25  ABSA GROUP LTD
# 26  ABU DHABI AIRPORTS COMPANY
# 27  ABU DHABI CUSTOMS
# 28  DEPARTMENT OF FINANCE ABU DHABI
# 29  SEHA ABU DHABI HEALTH SERVICES COMPANY
# 30  ABU DHABI INVESTMENT AUTHORITY
# 31  ABU DHABI QUALITY AND CONFORMITY COUNCIL
# 32  ABU DHABI TERMINALS
# 33  ACADEMISCH MEDISCH CENTRUM
# 34  ACADEMISCH ZIEKENHUIS MAASTRICHT
# 35  ACADEMISCH ZIEKENHUIS MAASTRICHT
# 36  ACADIA HEALTHCARE COMPANY INC
# 37  ACCENTURE
# 38  ACCOLADE WINES AUSTRALIA LTD
# 39
# 40  CEAT LTD
# 41  ACERO SCHOOL DISTRICT
# 42  ACH COLOMBIA S A
# 43  ACHMEA HOLDING NV
# 44
# 45  AIR NEW ZEALAND AIRCRAFT HOLDINGS LTD
# 46  BBVA SERVICIOS SA
# 47  ACT, INC
# 48
# 49  ADENA HEALTH SYSTEM
# 50  ADIDAS AG
# 51  AAR CORPORATION
# 52  ADIF ADMINISTRADOR DE INFRAESTRUCTURAS
# 53  ADOBE SYSTEMS INC
# 54  SPAR HOLDING AG
# 55
# 56  ADVANCED ENERGY INDUSTRIES INC
# 57  ADVANCED IT CONCEPTS INC
# 58  ADVANCED NETWORK MANAGEMENT
# 59  ADVANCED UNIBYTE GMBH
# 60  AAR CORPORATION
# 61  ADVENTIST HEALTH SYSTEMSUNBELT INC
# 62  ADVENTIST HEALTH SYSTEMWEST
# 63  ADVERTISING SPECIALTY INSTITUTE INC
# 64  CHAO SHI JIE INTERNATIONAL TECHNOLOGY (GUANGZHOU) CORPORATION
# 65  AERA ENERGY LLC
# 66  INC AEROJET ROCKETDYNE OF DE
# 67  AEROPORTS DE MONTREAL
# 68  AEROPORTS DE MONTREAL
# 69  AMGEN INC
# 70  ACT, INC
# 71  AFNI INC
# 72  AFREXIM BANK
# 73  AG2R
# 74  AGCO CORPORATION
# 75  AGDER IKT DRIFTSSENTER IKS
# 76
# 77  AGENCY FOR SCIENCE TECHNOLOGY AND RESEARCH
# 78  AGFA GEVAERT NV
# 79  AGILENT TECHNOLOGIES INC US
# 80  AGL ENERGY LTD
# 81  AGROPUR
# 82  AGROSTROJ PELHRIMOV AS
# 83  AGUA CALIENTE BAND OF CAHUILLA INDIANS
# 84  AHEAD LLC
# 85  AHT GLOBAL
# 86  ABSA GROUP LTD
# 87  AIR CANADA
# 88  AIRBNB UK LTD
# 89  AIRBUS DEFENCE & SPACE EDIFICIO INFORMATICA
# 90  AIRPORTS OF THAILAND PLC
# 91  AIRQUAY
# 92  TERANET ENTERPRISES INC
# 93  AKBANK
# 94  AKLAGARMYNDIGHETEN
# 95  AKRON PUBLIC SCHOOLS
# 96
# 97  AL SANAD INFORMATION TECHNOLOGY SERVICES
# 98  ALARM.COM INCORPORATED
# 99  ALASKA HEART INSTITUTE LLC

# %%
choices = cr_party_name['cr_party_name'].tolist()
process.extract("AARON'S INC", choices, limit=5, scorer=fuzz.token_set_ratio)
# Out:
# [('ARINC INC', 70),
#  ('ITRON INC', 70),
#  ('JSC CROC INC', 70),
#  ('MARCO INC', 70),
#  ('AMAZONCOM INC', 67)]
